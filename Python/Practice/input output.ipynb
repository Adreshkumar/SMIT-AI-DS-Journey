# %% [markdown]
# Variables

# %%
ab="Hello"
b=12
c=12.5
print("ab")
print(ab)
print(b)
print(c)
print(type(ab))
# Out:
# ab
# Hello
# 12
# 12.5
# <class 'str'>

# %% [markdown]
# Slicing

# %%
a="Hello World"
print(len(a))
print(a[0:5:1])
aa="Whats your name"
print(aa[1:10:2])
# Out:
# 11
# Hello
# ht or

# %% [markdown]
# Input

# %%
b=int(input("Whats Your number"))
print(b)
print("B",b)
bb=input("Enter Input")
print(bb)
# Out:
# 11
# B 11
# wkfy

# %% [markdown]
# Comments

# %%
# This is Comment This will not run anything this is for Adding message or writing so we can remember uses
