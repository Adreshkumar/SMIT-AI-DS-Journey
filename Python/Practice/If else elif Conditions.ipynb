# %% [markdown]
# ### Pass Fail Guess

# %%
num = 6576
if num >= 50:
    print("ok pass")
else:
    print("fail")
# Out:
# ok pass

# %% [markdown]
# ### Salary Ratings

# %%
salary=int(input("what is your salary"))
if salary >=82000:
 print("best")
elif salary >=9000:
 print("ok fine")
elif salary>=100:
 print("too low")
else:
 print("i will resign")
# Out:
# best

# %% [markdown]
# ### Good Bad Tempreture

# %%
temp=int(input("what's temp here bro"))
if temp>100:
    print("you are gonna die bro")
elif temp>50:
    print("50 50 chances")
elif temp>20:
    print("its normal")
else:
    print("too cold get some sweaters")
# Out:
# too cold get some sweaters

# %% [markdown]
# ### Positive Negative Numbers

# %%
user=int (input("enter number"))
if user>=0:
    print("positive")
else:
    print("negative")
# Out:
# negative

# %% [markdown]
# ### Login

# %%
username =input("enter your username")
userpass =input("enter password")
if username== "hello world" and userpass == "1345":
 print ("access granted")
else:
 print("access denied")
# Out:
# access granted

# %% [markdown]
# ### Age Verification

# %%
age =int(input("enter your age"))
if age>=18:
    print("GO Vote Now")
else:
    print("Be Adult KID")
# Out:
# Be Adult KID

# %% [markdown]
# ### Tempreture Rating 2

# %%
t=int(input("whats the temperature in celsius"))
if t>=40:
    print("very hot")
elif t>=25:
 print("moderate")
elif t<=25:
   print("cold")
# Out:
# very hot

# %% [markdown]
# ### Pin

# %%
PIN=int(input("enter your pin"))
if PIN == 1234:
    print("your balance is 1M")
else:
    print("access denied")
# Out:
# access denied
